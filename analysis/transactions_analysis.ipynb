# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Data/dataset_transacciones/hey_transacciones.csv")
df.head()
# Out:
#    transaccion_id    user_id   producto_id           fecha_hora  \
# 0  TXN-0000000055  USR-00001  PRD-00000002  2025-01-15 14:17:42
# 1  TXN-0000000048  USR-00001  PRD-00000001  2025-01-17 00:31:56
# 2  TXN-0000000018  USR-00001  PRD-00000001  2025-01-17 22:48:23
# 3  TXN-0000000043  USR-00001  PRD-00000001  2025-01-19 11:10:43
# 4  TXN-0000000009  USR-00001  PRD-00000001  2025-02-15 07:03:50
#
#      tipo_operacion        canal    monto comercio_nombre  \
# 0            compra      app_ios    33.88   DivertidoPark
# 1  cargo_recurrente      app_ios   249.00       GamerPass
# 2  cargo_recurrente   app_huawei   399.00   CloudDrive MX
# 3     transf_salida  app_android  8910.00             NaN
# 4            compra      app_ios   568.59    QuickBite MX
#
#          categoria_mcc    ciudad_transaccion  ... intento_numero  \
# 0      entretenimiento        Nueva York, NY  ...              1
# 1  servicios_digitales  CDMX - Benito Juárez  ...              1
# ...

# %%
df.isnull().sum() / len(df) *100
# Out:
# transaccion_id          0.000000
# user_id                 0.000000
# producto_id             0.000000
# fecha_hora              0.000000
# tipo_operacion          0.000000
# canal                   0.000000
# monto                   0.000000
# comercio_nombre        46.179635
# categoria_mcc           0.000000
# ciudad_transaccion      2.401219
# estatus                 0.000000
# motivo_no_procesada    96.683757
# intento_numero          0.000000
# meses_diferidos        97.842305
# cashback_generado      77.487338
# descripcion_libre       7.696066
# hora_del_dia            0.000000
# dia_semana              0.000000
# es_internacional        0.000000
# dispositivo            25.182830
# patron_uso_atipico      0.000000
# es_dato_sintetico       0.000000
# dtype: float64
